# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/yoma/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
img1 = cv2.imread('img/sample1.jpg')
img2 = cv2.imread('img/sample2.jpg')

# %%
t1 = cv2.getTickCount()
orb = cv2.ORB_create(10000)
kp1, des1 = orb.detectAndCompute(img1, None)
kp2, des2 = orb.detectAndCompute(img2, None)
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x: x.distance)
t2 = cv2.getTickCount()
t = (t2-t1)/cv2.getTickFrequency()
print t
# Out:
# 0.175569968

# %%
img3 = cv2.drawMatches(img1, kp1, img2, kp2, matches[:1000], None, flags=2)
plt.imshow(img3)
plt.show()
